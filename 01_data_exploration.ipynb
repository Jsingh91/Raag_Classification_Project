# %%
import pdfplumber

# %%
with pdfplumber.open("Siri Guru Granth Sahib in Gurmukhi, with Index (Uni).pdf") as pdf:
    print(len(pdf.pages))
# Out:
# 1483

# %%
with pdfplumber.open("Siri Guru Granth Sahib in Gurmukhi, with Index (Uni).pdf") as pdf:
    first_page = pdf.pages[0]
    first_page_text = first_page.extract_text()
    print(first_page_text)
# Out:
# 1
# ❁❁❁❁❁❁❁❁❁❁❁❁❁❁ ❁❁❁❁❁❁❁❁❁❁❁❁❁❁
# ❁
# ❁
# ❁
# ❁ ੧ਓ ਸਤਿਗੁਰ ਪ੍ਰਸਾਤਿ ॥ ਰਾਗੁ ਟੋਡੀ ............................... ੭੧੧ ਰਾਗੁ ਪ੍ਰਭਾਿੀ ........................ ੧੩੨੭
# ❁
# ❁ ਰਾਗੁ ਿੈਰਾੜੀ ............................੭੧੯ ਰਾਗੁ ਜੈਜਾਵੰਿੀ ...................... ੧੩੫੨
# ਿਿਕਰਾ ਰਾਗਾਂ ਕਾ
# ❁
# ❁ ਰਾਗੁ ਤਿਲੰਗ ............................ ੭੨੧ ਸਲੋਕ ਸਿਸਤਿਿੀ ਮਿਲਾ ੧ .... ੧੩੫੩
# ਰਾਗ ........................................ ਪ੍ੰਨਾ ❁
# ❁ ਰਾਗੁ ਸੂਿੀ .............................. ੭੨੮ ਸਲੋਕ ਸਿਸਤਿਿੀ ਮਿਲਾ ੫ .... ੧੩੫੩
# ਜਪ੍ੁ ........................................... ੧
# ❁
# ❁ ਰਾਗੁ ਤਿਲਾਵਲੁ ........................ ੭੯੫ ਮਿਲਾ ੫ ਗਾਥਾ .....................੧੩੬੦
# ਸੋ ਿਰੁ ........................................ ੮
# ❁
# ❁ ਰਾਗੁ ਗੋੋਂਡ .............................. ੮੫੯ ਫੁਨਿੇ ਮਿਲਾ ੫ ..................... ੧੩੬੧
# ਸੋ ਪ੍ੁਰਖੁ ................................... ੧੦
# ❁
# ❁ ਰਾਗੁ ਰਾਮਕਲੀ ......................... ੮੭੬ ਚਉਿੋਲੇ ਮਿਲਾ ੫ .................. ੧੩੬੩
# ਸੋਤਿਲਾ ................................... ੧੨
# ❁
# ❁ ਰਾਗੁ ਨਟ ਨਾਰਾਇਨ ................. ੯੭੫ ਸਲੋਕ ਭਗਿ ਕਿੀਰ ਜੀਉ ਕੇ ..... ੧੩੬੪
# ਤਸਰੀ ਰਾਗੁ ................................ ੧੪
# ❁
# ❁ ਰਾਗੁ ਮਾਲੀ ਗਉੜਾ ................... ੯੮੪ ਸਲੋਕ ਸੇਖ ਫਰੀਿ ਕੇ .............. ੧੩੭੭
# ਰਾਗੁ ਮਾਝ ................................. ੯੪
# ❁
# ❁ ਰਾਗੁ ਮਾਰੂ .............................. ੯੮੯ ਸਵਯੇ ਸਰੀ ਮੁਖ ਿਾਕ ਮਿਲਾ ੫ ... ੧੩੮੫
# ਰਾਗੁ ਗਉੜੀ ............................ ੧੫੧
# ❁
# ❁ ਰਾਗੁ ਿੁਖਾਰੀ ......................... ੧੧੦੭ ਸਲੋਕ ਵਾਰਾਂ ਿੇ ਵਧੀਕ ............ ੧੪੧੦
# ਰਾਗੁ ਆਸਾ ............................ ੩੪੭
# ❁
# ❁ ਰਾਗੁ ਕੇਿਾਰਾ ........................ ੧੧੧੮ ਸਲੋਕ ਮਿਲਾ ੯ .................... ੧੪੨੬
# ਰਾਗੁ ਗੂਜਰੀ............................ ੪੮੯
# ❁
# ❁ ਰਾਗੁ ਭੈਰਉ .......................... ੧੧੨੫ ਮੁੰਿਾਵਣੀ ਮਿਲਾ ੫ ................ ੧੪੨੯
# ਰਾਗੁ ਿੇਵਗੰਧਾਰੀ ...................... ੫੨੭
# ❁
# ❁ ਰਾਗੁ ਿਸੰਿੁ .......................... ੧੧੬੮ ਰਾਗਮਾਲਾ ........................... ੧੪੨੯
# ਰਾਗੁ ਤਿਿਾਗੜਾ ....................... ੫੩੭
# ❁ ਰਾਗੁ ਸਾਰਗ ......................... ੧੧੯੭ ❁
# ਰਾਗੁ ਵਡਿੰਸੁ ........................... ੫੫੭
# ❁ ਰਾਗੁ ਮਲਾਰ ......................... ੧੨੫੪ ❁
# ਰਾਗੁ ਸੋਰਤਿ ............................ ੫੯੫
# ❁ ਰਾਗੁ ਕਾਨੜਾ ........................ ੧੨੯੪ ❁
# ਰਾਗੁ ਧਨਾਸਰੀ ......................... ੬੬੦
# ❁ ਰਾਗੁ ਕਤਲਆਨ ..................... ੧੩੧੯ ❁
# ਰਾਗੁ ਜੈਿਸਰੀ .......................... ੬੯੬
# ❁
# ❁
# ❁
# ❁❁ ❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁

# %%
pdf = pdfplumber.open("Siri Guru Granth Sahib in Gurmukhi, with Index (Uni).pdf")

# %%
gurbani_full_text_pages = pdf.pages[:1483]
gurbani_full_text = [page.extract_text() for page in gurbani_full_text_pages]

# %%
all_text = " ".join(gurbani_full_text)

# %%
total_count = all_text.count("ਪ੍ਰਸਾਤਿ")

# %%
print(total_count)
# Out:
# 831

# %%
total_count_2 = all_text.count("ਪ੍ਰਸਾਦਿ")
print(total_count_2)
# Out:
# 0

# %%
mahalla_count = all_text.count("ਮਿਲਾ")
print(mahalla_count)
# Out:
# 2900

# %%
# Find the position of the first few occurrences of "ਮਿਲਾ" and print some context around them
position = all_text.find("ਮਿਲਾ",240000)
print(position)
all_text[position-2000:position+1000]
# Out:
# 240051
# 'ਗੁਰੁ ਸਾਲਾਿੀਐ ਕਰਣ ਕਾਰਣ ਸਮਰਥੁ ॥ ਸੇ ਮਥੇ ❁\n❁ ❁\nਤਨਿਚਲ ਰਿੇ ਤਜਨ ਗੁਤਰ ਧਾਤਰਆ ਿਥੁ ॥ ਗੁਤਰ ਅੰਤਮਰਿ ਨਾਮੁ ਪ੍ੀਆਤਲਆ ਜਨਮ ਮਰਨ ਕਾ ਪ੍ਥੁ ॥ ਗੁਰੁ\n❁ ❁\n❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁ ❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁ 50 ❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁\n❁ ❁\n❁ ਪ੍ਰਮੇਸਰੁ ਸੇਤਵਆ ਭੈ ਭੰਜਨੁ ਿੁਖ ਲਥੁ ॥੩॥ ਸਤਿਗੁਰੁ ਗਤਿਰ ਗਭੀਰੁ ਿੈ ਸੁਖ ਸਾਗਰੁ ਅਘਖੰਡੁ ॥ ਤਜਤਨ ਗੁਰੁ ❁\n❁ ਸੇਤਵਆ ਆਪ੍ਣਾ ਜਮਿੂਿ ਨ ਲਾਗੈ ਡੰਡੁ ॥ ਗੁਰ ਨਾਤਲ ਿੁਤਲ ਨ ਲਗਈ ਖੋਤਜ ਤਡਿਾ ਿਰਿਮੰਡੁ ॥ ਨਾਮੁ ਤਨਧਾਨੁ ❁\n❁ ❁\nਸਤਿਗੁਤਰ ਿੀਆ ਸੁਖੁ ਨਾਨਕ ਮਨ ਮਤਿ ਮੰਡੁ ॥੪॥੨੦॥੯੦॥ ਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ॥ ਤਮਿਾ ਕਤਰ ਕੈ ਖਾਇਆ\n❁ ❁\nਕਉੜਾ ਉਪ੍ਤਜਆ ਸਾਿੁ ॥ ਭਾਈ ਮੀਿ ਸੁਤਰਿ ਕੀਏ ਤਿਤਖਆ ਰਤਚਆ ਿਾਿੁ ॥ ਜਾਂਿੇ ਤਿਲਮ ਨ ਿੋਵਈ ਤਵਣੁ\n❁ ❁\nਨਾਵੈ ਤਿਸਮਾਿੁ ॥੧॥ ਮੇਰੇ ਮਨ ਸਿਗੁਰ ਕੀ ਸਵੇ ਾ ਲਾਗੁ ॥ ਜੋ ਿੀਸੈ ਸੋ ਤਵਣਸਣਾ ਮਨ ਕੀ ਮਤਿ ਤਿਆਗੁ ॥੧॥\n❁ ❁\nਰਿਾਉ ॥ ਤਜਉ ਕੂਕਰੁ ਿਰਕਾਇਆ ਧਾਵੈ ਿਿ ਤਿਸ ਜਾਇ ॥ ਲੋਭੀ ਜੰਿੁ ਨ ਜਾਣਈ ਭਖੁ ਅਭਖੁ ਸਭ ਖਾਇ ॥\n❁ ❁\nਕਾਮ ਿੋਧ ਮਤਿ ਤਿਆਤਪ੍ਆ ਤਫਤਰ ਤਫਤਰ ਜੋਨੀ ਪ੍ਾਇ ॥੨॥ ਮਾਇਆ ਜਾਲੁ ਪ੍ਸਾਤਰਆ ਭੀਿਤਰ ਚੋਗ ਿਣਾਇ ॥\n❁ ❁\nਤਿਰਸਨਾ ਪ੍ੰਖੀ ਫਾਤਸਆ ਤਨਕਸੁ ਨ ਪ੍ਾਏ ਮਾਇ ॥ ਤਜਤਨ ਕੀਿਾ ਤਿਸਤਿ ਨ ਜਾਣਈ ਤਫਤਰ ਤਫਤਰ ਆਵੈ ਜਾਇ\n❁ ❁\n❁ ॥੩॥ ਅਤਨਕ ਪ੍ਰਕਾਰੀ ਮੋਤਿਆ ਿਿੁ ਤਿਤਧ ਇਿੁ ਸੰਸਾਰੁ ॥ ਤਜਸ ਨੋ ਰਖੈ ਸੋ ਰਿੈ ਸੰਤਮਰਥੁ ਪ੍ੁਰਖੁ ਅਪ੍ਾਰੁ ॥ ਿਤਰ ❁\n❁ ਜਨ ਿਤਰ ਤਲਵ ਉਧਰੇ ਨਾਨਕ ਸਿ ਿਤਲਿਾਰੁ ॥੪॥੨੧॥੯੧॥ ਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ਘਰੁ ੨॥ ਗੋਇਤਲ ❁\n❁ ❁\nਆਇਆ ਗੋਇਲੀ ਤਕਆ ਤਿਸੁ ਡੰਫੁ ਪ੍ਸਾਰੁ ॥ ਮੁਿਲਤਿ ਪ੍ੁੰਨੀ ਚਲਣਾ ਿੂੰ ਸੰਮਲੁ ਘਰ ਿਾਰੁ ॥੧॥ ਿਤਰ ਗੁਣ\n❁ ❁\nਗਾਉ ਮਨਾ ਸਤਿਗੁਰੁ ਸੇਤਵ ਤਪ੍ਆਤਰ ॥ ਤਕਆ ਥੋੜੜੀ ਿਾਿ ਗੁਮਾਨੁ ॥੧॥ ਰਿਾਉ ॥ ਜੈਸੇ ਰੈਤਣ ਪ੍ਰਾਿੁਣੇ\n❁ ❁\nਉਤਿ ਚਲਸਤਿ ਪ੍ਰਭਾਤਿ ॥ ਤਕਆ ਿੂੰ ਰਿਾ ਤਗਰਸਿ ਤਸਉ ਸਭ ਫੁਲਾ ਕੀ ਿਾਗਾਤਿ ॥੨॥ ਮੇਰੀ ਮੇਰੀ ਤਕਆ\n❁ ❁\nਕਰਤਿ ਤਜਤਨ ਿੀਆ ਸੋ ਪ੍ਰਭੁ ਲੋਤੜ ॥ ਸਰਪ੍ਰ ਉਿੀ ਚਲਣਾ ਛਤਡ ਜਾਸੀ ਲਖ ਕਰੋਤੜ ॥੩॥ ਲਖ ਚਉਰਾਸੀਿ\n❁ ❁\nਭਰਮਤਿਆ ਿੁਲਭ ਜਨਮੁ ਪ੍ਾਇਓਇ ॥ ਨਾਨਕ ਨਾਮੁ ਸਮਾਤਲ ਿੂੰ ਸੋ ਤਿਨੁ ਨੇੜਾ ਆਇਓਇ ॥੪॥੨੨॥੯੨॥\n❁ ❁\nਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ॥ ਤਿਚਰੁ ਵਸਤਿ ਸੁਿੇਲੜੀ ਤਜਚਰੁ ਸਾਥੀ ਨਾਤਲ ॥ ਜਾ ਸਾਥੀ ਉਿੀ ਚਤਲਆ ਿਾ ਧਨ ਖਾਕੂ\n❁ ❁\n❁ ਰਾਤਲ ॥੧॥ ਮਤਨ ਿੈਰਾਗੁ ਭਇਆ ਿਰਸਨੁ ਿਖੇ ਣੈ ਕਾ ਚਾਉ ॥ ਧੰਨੁ ਸੁ ਿੇਰਾ ਥਾਨੁ ॥੧॥ ਰਿਾਉ ॥ ਤਜਚਰੁ ਵਤਸਆ ❁\n❁ ਕੰਿੁ ਘਤਰ ਜੀਉ ਜੀਉ ਸਤਭ ਕਿਾਤਿ ॥ ਜਾ ਉਿੀ ਚਲਸੀ ਕੰਿੜਾ ਿਾ ਕੋਇ ਨ ਪ੍ੁਛੈ ਿੇਰੀ ਿਾਿ ॥੨॥ ਪ੍ੇਈਅੜੈ ਸਿੁ ❁\n❁ ❁\nਸੇਤਵ ਿੂੰ ਸਾਿੁਰੜੈ ਸੁਤਖ ਵਸੁ ॥ ਗੁਰ ਤਮਤਲ ਚਜੁ ਅਚਾਰੁ ਤਸਖੁ ਿੁਧੁ ਕਿੇ ਨ ਲਗੈ ਿੁਖੁ ॥੩॥ ਸਭਨਾ ਸਾਿੁਰੈ ਵੰਞਣਾ\n❁ ❁\n❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁ ❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁ 51 ❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁❁\n❁ ❁\n❁ ਸਤਭ ਮੁਕਲਾਵਣਿਾਰ ॥ ਨਾਨਕ ਧੰਨੁ ਸੋਿਾਗਣੀ ਤਜਨ ਸਿ ਨਾਤਲ ਤਪ੍ਆਰੁ ॥੪॥੨੩॥੯੩॥ ❁\n❁ ਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ਘਰੁ ੬॥ ਕਰਣ ਕਾਰਣ ਏਕੁ ਓਿੀ ਤਜਤਨ ਕੀਆ ਆਕਾਰੁ ॥ ਤਿਸਤਿ ਤਧਆਵਿੁ ਮਨ ਮੇਰੇ ❁\n❁ ❁\nਸਰਿ ਕੋ ਆਧਾਰੁ ॥੧॥ ਗੁਰ ਕੇ ਚਰਨ ਮਨ ਮਤਿ ਤਧਆਇ ॥ ਛੋਤਡ ਸਗਲ ਤਸਆਣਪ੍ਾ ਸਾਤਚ ਸਿਤਿ ਤਲਵ\n❁ ❁\nਲਾਇ ॥੧॥ ਰਿਾਉ ॥ ਿੁਖੁ ਕਲੇਸੁ ਨ ਭਉ ਤਿਆਪ੍ੈ ਗੁਰ ਮੰਿੁ ਤਿਰਿੈ ਿੋਇ ॥ ਕੋਤਟ ਜਿਨਾ ਕਤਰ ਰਿੇ ਗੁਰ ਤਿਨੁ\n❁ ❁\nਿਤਰਓ ਨ ਕੋਇ ॥੨॥ ਿੇਤਖ ਿਰਸਨੁ ਮਨੁ ਸਾਧਾਰੈ ਪ੍ਾਪ੍ ਸਗਲੇ ਜਾਤਿ ॥ ਿਉ ਤਿਨ ਕੈ ਿਤਲਿਾਰਣੈ ਤਜ ਗੁਰ ਕੀ\n❁ ❁\nਪ੍ੈਰੀ ਪ੍ਾਤਿ ॥੩॥ ਸਾਧਸੰਗਤਿ ਮਤਨ ਵਸੈ ਸਾਚੁ ਿਤਰ ਕਾ ਨਾਉ ॥ ਸੇ ਵਡਭਾਗੀ ਨਾਨਕਾ ਤਜਨਾ ਮਤਨ ਇਿੁ ਭਾਉ\n❁ ❁\n॥੪॥੨੪॥੯੪॥ ਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ॥ ਸੰਤਚ ਿਤਰ ਧਨੁ ਪ੍ੂਤਜ ਸਤਿਗੁਰੁ ਛੋਤਡ ਸਗਲ ਤਵਕਾਰ ॥ ਤਜਤਨ ਿੂੰ ਸਾਤਜ\n❁ ❁\nਸਵਾਤਰਆ ਿਤਰ ਤਸਮਤਰ ਿੋਇ ਉਧਾਰੁ ॥੧॥ ਜਤਪ੍ ਮਨ ਨਾਮੁ ਏਕੁ ਅਪ੍ਾਰੁ ॥ ਪ੍ਰਾਨ ਮਨੁ ਿਨੁ ਤਜਨਤਿ ਿੀਆ\n❁ ❁\n❁ ਤਰਿੇ ਕਾ ਆਧਾਰੁ ॥੧॥ ਰਿਾਉ ॥ ਕਾਤਮ ਿੋਤਧ ਅਿੰਕਾਤਰ ਮਾਿੇ ਤਵਆਤਪ੍ਆ ਸੰਸਾਰੁ ॥ ਪ੍ਉ ਸੰਿ ਸਰਣੀ ਲਾਗੁ ❁\n❁ ਚਰਣੀ ਤਮਟੈ ਿੂਖੁ ਅੰਧਾਰੁ ॥੨॥ ਸਿੁ ਸੰਿੋਖੁ ਿਇਆ ਕਮਾਵੈ ਏਿ ਕਰਣੀ ਸਾਰ ॥ ਆਪ੍ੁ ਛੋਤਡ ਸਭ ਿੋਇ ਰੇਣਾ ❁\n❁ ❁\nਤਜਸੁ ਿੇਇ ਪ੍ਰਭੁ ਤਨਰੰਕਾਰੁ ॥੩॥ ਜੋ ਿੀਸੈ ਸੋ ਸਗਲ ਿੂੰਿੈ ਪ੍ਸਤਰਆ ਪ੍ਾਸਾਰੁ ॥ ਕਿੁ ਨਾਨਕ ਗੁਤਰ ਭਰਮੁ\n❁ ❁\nਕਾਤਟਆ ਸਗਲ ਿਰਿਮ ਿੀਚਾਰੁ ॥੪॥੨੫॥੯੫॥ ਤਸਰੀਰਾਗੁ ਮਿਲਾ ੫ ॥ ਿੁਤਿਿ ਸੁਤਿਿ ਮੰਧੇ ਸੰਸਾਰੁ\n❁ ❁\nਸਗਲਾਣਾ ॥ ਿੁਿਿੂ ੰ ਿੇ ਰਿਿ ਭਗਿੁ ਿੈ ਕੋਈ ਤਵਰਲਾ ਜਾਣਾ ॥੧॥ ਿਾਕੁਰੁ ਸਰਿੇ'

# %%
import re

gurmukhi_pattern = r"([\u0A00-\u0A7F]+)\s+ਮਿਲਾ\s+([\u0A00-\u0A7F]+)"
matches = re.findall(gurmukhi_pattern,all_text)
print(f"Found {len(matches)} matches")
print(matches[:10])
# Out:
# Found 2688 matches
# [('ਸਿਸਤਿਿੀ', '੧'), ('ਸਿਸਤਿਿੀ', '੫'), ('੭੯੫', '੫'), ('ਫੁਨਿੇ', '੫'), ('ਚਉਿੋਲੇ', '੫'), ('ਿਾਕ', '੫'), ('ਸਲੋਕ', '੯'), ('ਮੁੰਿਾਵਣੀ', '੫'), ('੨੯', '੧'), ('੧੮', '੩')]

# %%
filtered_matches = [match for match in matches if not match[0].isdigit()]

# %%
filtered_matches[:20]
# Out:
# [('ਸਿਸਤਿਿੀ', '੧'),
#  ('ਸਿਸਤਿਿੀ', '੫'),
#  ('ਫੁਨਿੇ', '੫'),
#  ('ਚਉਿੋਲੇ', '੫'),
#  ('ਿਾਕ', '੫'),
#  ('ਸਲੋਕ', '੯'),
#  ('ਮੁੰਿਾਵਣੀ', '੫'),
#  ('ਵਾਰ', '੪'),
#  ('ਜੀਉ', '੪'),
#  ('ਅਸਟਪ੍ਿੀਆ', '੧'),
#  ('ਮਾਂਝ', '੫'),
#  ('ਕੀ', '੧'),
#  ('ਗਉੜੀ', '੩'),
#  ('ਅਸਟਪ੍ਿੀਆ', '੧'),
#  ('ਛੰਿ', '੧'),
#  ('ਛੰਿ', '੩'),
#  ('ਛੰਿ', '੫'),
#  ('ਅਖਰੀ', '੫'),
#  ('ਗਉੜੀ', '੫'),
#  ('ਵਾਰ', '੪')]

# %%
len(filtered_matches)
# Out:
# 2567
