# %% [markdown]
# # Raag Classification Project – 01 Exploration of Raw Text
#
# **Goal of this notebook**
#
# - Load the Guru Granth Sahib PDF using the production `pdf_loader` code.
# - Inspect the raw text to understand its structure (pages, line breaks, special characters).
#
#
# **Context**
#
# This notebook is for *exploration only*. The real, reusable logic for loading the PDF lives in:
# - `src/Raag_Project/pdf_loader.py` (production code)
#
# Any useful ideas from this notebook will later be turned into proper functions in the production codebase.

# %% [markdown]
# ## 1. Imports and setup

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent

src_path = project_root/"src"

sys.path.append(str(src_path))

# %% [markdown]
# ## 2. Load PDF using production loader

# %%
from Raag_Project.pdf_loader import load_pdf_text

# %% [markdown]
# ## 3. Basic sanity checks on the text

# %%
pdf_path = "../data/raw_text/Gurbani_with_index_Uni.pdf"
gurbani_pdf_text = load_pdf_text(pdf_path)
gurbani_pdf_text[:500]
# Out:
# '1\n❁❁❁❁❁❁❁❁❁❁❁❁❁❁ ❁❁❁❁❁❁❁❁❁❁❁❁❁❁\n❁\n❁\n❁\n❁ ੧ਓ ਸਤਿਗੁਰ ਪ੍ਰਸਾਤਿ ॥ ਰਾਗੁ ਟੋਡੀ ............................... ੭੧੧ ਰਾਗੁ ਪ੍ਰਭਾਿੀ ........................ ੧੩੨੭\n❁\n❁ ਰਾਗੁ ਿੈਰਾੜੀ ............................੭੧੯ ਰਾਗੁ ਜੈਜਾਵੰਿੀ ...................... ੧੩੫੨\nਿਿਕਰਾ ਰਾਗਾਂ ਕਾ\n❁\n❁ ਰਾਗੁ ਤਿਲੰਗ ............................ ੭੨੧ ਸਲੋਕ ਸਿਸਤਿਿੀ ਮਿਲਾ ੧ .... ੧੩੫੩\nਰਾਗ ........................................ ਪ੍ੰਨਾ ❁\n❁ ਰਾਗੁ ਸੂਿੀ .............................. ੭੨੮ ਸਲੋਕ ਸਿਸਤਿਿੀ ਮਿਲਾ ੫ .... ੧੩੫੩\nਜਪ੍ੁ .................................'

# %% [markdown]
# ## Write the PDF file to a Txt File

# %%
from Raag_Project.pdf_loader import get_txt_file

gurbani_txt_file = get_txt_file(gurbani_pdf_text)
